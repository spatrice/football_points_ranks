# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('data/predictiontest.csv')
del df[df.columns[0]]

# %%
# Convert create_month to datetime if it's not already in datetime format
df['create_month'] = pd.to_datetime(df['create_month'])
df.head()
# Out:
#   create_month      antrieb          bodytype  i_preis_verkauf  \
# 0   2018-04-01  Andere/Null  Andere/Unbekannt            12500
# 1   2018-04-01  Andere/Null  Andere/Unbekannt            12900
# 2   2018-04-01  Andere/Null  Andere/Unbekannt            14300
# 3   2018-04-01  Andere/Null  Andere/Unbekannt            14800
# 4   2018-04-01  Andere/Null  Andere/Unbekannt            15300
#
#          s_neupreis  i_leistung_ps  alter_fahrzeug_tage  s_marke  \
# 0  Andere/Unbekannt            164                  400      BMW
# 1  Andere/Unbekannt            101                 1826   TOYOTA
# 2             27750            125                 1311  PEUGEOT
# 3             30300            112                  763     FORD
# 4  Andere/Unbekannt             90                  240   SUZUKI
#
#    count_monthly_all  mean_price_month_all  ...  count_monthly_kleinwagen  \
# 0              59022           19115.57936  ...                      7505
# ...

# %%
# Split the data into training and testing sets
train_data = df[df['create_month'] < '2023-01-01']  # Training data
test_data = df[df['create_month'] >= '2023-01-01']  # Testing data

# %%
# Select the features and target variable for training
X_train = train_data.drop('mean_price_month_all', axis=1)
y_train = train_data['mean_price_month_all']
y_train.head()
# Out:
# 0    19115.57936
# 1    19115.57936
# 2    19115.57936
# 3    19115.57936
# 4    19115.57936
# Name: mean_price_month_all, dtype: float64

# %%
# Train the Random Forest model
rf_model = RandomForestRegressor()
rf_model.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [34], line 3
#       1 # Train the Random Forest model
#       2 rf_model = RandomForestRegressor()
# ----> 3 rf_model.fit(X_train, y_train)
#
# File ~/.pyenv/versions/3.11.0/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:345, in BaseForest.fit(self, X, y, sample_weight)
#     343 if issparse(y):
#     344     raise ValueError("sparse multilabel-indicator for y is not supported.")
# --> 345 X, y = self._validate_data(
#     346     X, y, multi_output=True, accept_sparse="csc", dtype=DTYPE
#     347 )
#     348 if sample_weight is not None:
#     349     sample_weight = _check_sample_weight(sample_weight, X)
#
# File ~/.pyenv/versions/3.11.0/lib/python3.11/site-packages/sklearn/base.py:584, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
# ...

# %%
# Predict the prices for the next 6 months
X_test = test_data.drop('mean_price_month_all', axis=1)
prediction = rf_model.predict(X_test)

# Add the predicted prices to the test_data DataFrame
test_data['predicted_price'] = prediction

# Plot the actual and predicted prices with uncertainty
plt.figure(figsize=(10, 6))
sns.lineplot(data=df, x='create_month', y='mean_price_month_all', label='Actual')
sns.lineplot(data=test_data, x='create_month', y='predicted_price', label='Predicted')
plt.fill_between(test_data['create_month'], test_data['predicted_price'] - 2*test_data['predicted_price'].std(),
                 test_data['predicted_price'] + 2*test_data['predicted_price'].std(), alpha=0.3, color='orange')
plt.xlabel('Month')
plt.ylabel('Price')
plt.title('Actual vs. Predicted Car Prices with Uncertainty')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [19], line 3
#       1 # Train the Random Forest model
#       2 rf_model = RandomForestRegressor()
# ----> 3 rf_model.fit(X_train, y_train)
#       5 # Predict the prices for the next 6 months
#       6 X_test = test_data.drop('mean_price_month_all', axis=1)
#
# File ~/.pyenv/versions/3.11.0/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:345, in BaseForest.fit(self, X, y, sample_weight)
#     343 if issparse(y):
#     344     raise ValueError("sparse multilabel-indicator for y is not supported.")
# --> 345 X, y = self._validate_data(
#     346     X, y, multi_output=True, accept_sparse="csc", dtype=DTYPE
#     347 )
#     348 if sample_weight is not None:
#     349     sample_weight = _check_sample_weight(sample_weight, X)
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [37], line 9
#       6 # Convert create_month to numeric representation
#       7 df['create_month'] = pd.to_numeric(df['create_month'])
# ----> 9 train_data = df[pd.Timestamp(df['create_month']) < pd.Timestamp('2023-01-01')]  # Training data
#      10 test_data = df[pd.Timestamp(df['create_month']) >= pd.Timestamp('2023-01-01')]  # Testing data
#      12 # Select the features and target variable for training
#
# File ~/.pyenv/versions/3.11.0/lib/python3.11/site-packages/pandas/_libs/tslibs/timestamps.pyx:1698, in pandas._libs.tslibs.timestamps.Timestamp.__new__()
#
# File ~/.pyenv/versions/3.11.0/lib/python3.11/site-packages/pandas/_libs/tslibs/conversion.pyx:309, in pandas._libs.tslibs.conversion.convert_to_tsobject()
#
# TypeError: Cannot convert input [0          1522540800000000000
# 1          1522540800000000000
# ...
